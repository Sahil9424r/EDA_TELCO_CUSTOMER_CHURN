# %%
# !kaggle datasets download blastchar/telco-customer-churn
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/blastchar/telco-customer-churn
# License(s): copyright-authors
# ...
#   0% 0.00/172k [00:00<?, ?B/s]
# 100% 172k/172k [00:00<00:00, 34.5MB/s]

# %%
# !unzip -o /content/telco-customer-churn.zip
# Out:
# Archive:  /content/telco-customer-churn.zip
#   inflating: WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df1=df.copy()

# %%
df1.shape
# Out:
# (7043, 21)

# %%
df1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df1.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df1.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df1.MonthlyCharges=df1.MonthlyCharges.astype('float')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges,errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.SeniorCitizen=df1.SeniorCitizen.replace({0:'No',1:'Yes'})

# %%
df1.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# EDA

# %%
df1.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# sns.countplot(x='Churn',data=df1)
ax = sns.countplot(x='Churn', data=df1)
ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.pie(df1.Churn.value_counts(),labels=df1.Churn.value_counts().index,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# reson behinf above

# %%
sns.countplot(x='gender',hue='Churn',data=df1)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# as almost same so,churn is not gender specififc

# %%
sns.countplot(x='SeniorCitizen',hue='Churn',data=df1)
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# stack bar plot
# shows percent

# %%
counts = df1.groupby(['SeniorCitizen', 'Churn']).size().unstack()

# Convert counts to percentages
percentages = counts.div(counts.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
ax = percentages.plot(kind='bar', stacked=True, colormap='viridis', figsize=(8,6))

# Add percentage labels
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f%%', label_type='center', fontsize=12, color='white', weight='bold')

plt.ylabel("Percentage")
plt.title("Churn Distribution by Senior Citizen Status")
plt.xticks(rotation=0)  # Keep x labels horizontal
plt.legend(title="Churn")
plt.show()

# %% [markdown]
# a greater % of peopel who are senior citizen are chunred out

# %%
sns.histplot(x='tenure',data=df1,hue='Churn',bins=72)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [markdown]
# we have seen that start monts mein more churn hai

# %%
sns.countplot(x='Contract',data=df1,hue='Churn')
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
counts = df1.groupby(['Contract', 'Churn']).size().unstack()

# Convert counts to percentages
percentages = counts.div(counts.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
ax = percentages.plot(kind='bar', stacked=True, colormap='viridis', figsize=(8,6))

# Add percentage labels
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f%%', label_type='center', fontsize=12, color='white', weight='bold')

plt.ylabel("Percentage")
plt.title("Churn Distribution by Contract Type")
plt.xticks(rotation=0)  # Keep x labels horizontal
plt.legend(title="Churn")
plt.show()

# %% [markdown]
# month to month contract wale more churn ,and more people are of this type

# %%
df1.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# List of columns to plot
cols = ['PhoneService', 'MultipleLines', 'InternetService',
        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
        'StreamingTV', 'StreamingMovies']

# Create subplots (3 rows, 3 columns)
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle("Count Plots for Various Services", fontsize=16)

# Loop through each column and plot on its respective subplot
for i, col in enumerate(cols):
    row, col_idx = divmod(i, 3)  # Get row and column index
    ax = sns.countplot(x=col, ax=axes[row, col_idx],hue='Churn',data=df1)
    axes[row, col_idx].set_title(col)  # Set title for each subplot

    # Add count labels on top of bars
    for bar in ax.patches:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
                int(bar.get_height()), ha='center', va='bottom', fontsize=10, fontweight='bold')

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# Here are the key insights from the subplots:
#
# Phone Service:
#
# Most customers have phone service.
# Churn is higher among those with phone service, but the proportion is relatively low.
# Multiple Lines:
#
# Customers with a single phone line and those with multiple lines have similar churn rates.
# Those without phone service have significantly lower churn numbers.
# Internet Service:
#
# Customers using Fiber optic internet have a higher churn rate compared to DSL users.
# Customers with no internet service have a much lower churn count.
# Online Security & Online Backup:
#
# Customers without these services tend to churn more.
# Those with online security or backup enabled have lower churn rates.
# Device Protection & Tech Support:
#
# Similar to online security, customers without these services churn more.
# Providing these services might help retain customers.
# Streaming TV & Streaming Movies:
#
# Customers using streaming services tend to have higher churn rates.
# Customers without internet service have lower churn, possibly indicating less dependency on digital services.
# 🔹 Overall Findings:
# Customers who lack security, backup, or support services churn more.
# Fiber optic users have the highest churn—possible dissatisfaction with service or pricing.
# Streaming services may contribute to churn—possible dissatisfaction with bundle pricing.

# %%
counts = df1.groupby(['PaymentMethod', 'Churn']).size().unstack()

# Convert counts to percentages
percentages = counts.div(counts.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
ax = percentages.plot(kind='bar', stacked=True, colormap='viridis', figsize=(8,6))

# Add percentage labels
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f%%', label_type='center', fontsize=12, color='white', weight='bold')

plt.ylabel("Percentage")
plt.title("Churn Distribution by PaymentMethod Type")
plt.xticks(rotation=0)  # Keep x labels horizontal
plt.legend(title="Churn")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# electronic check wale more churn

# %%
counts = df1.groupby(['PaperlessBilling', 'Churn']).size().unstack()

# Convert counts to percentages
percentages = counts.div(counts.sum(axis=1), axis=0) * 100

# Plot stacked bar chart
ax = percentages.plot(kind='bar', stacked=True, colormap='viridis', figsize=(8,6))

# Add percentage labels
for bars in ax.containers:
    ax.bar_label(bars, fmt='%.1f%%', label_type='center', fontsize=12, color='white', weight='bold')

plt.ylabel("Percentage")
plt.title("Churn Distribution by PaperlessBilling Type")
plt.xticks(rotation=0)  # Keep x labels horizontal
plt.legend(title="Churn")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# paperless billing more likely to churn that have paperless billing
